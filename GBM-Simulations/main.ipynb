# %%
from GBM_simulator import GBM as GBM_Simulation
from GBM_pricer import GBM_formula as GBM_Pricer
import numpy as np

# Parameters
s_0 = 100
iterations = 1000  # T = iteration * dt = 1000 * 0.01 = 10
mu = 0.05
sigma = 0.2
num_paths = 100
t = 10
W_t = 0.0  # Mean of Brownian motion

# Run simulation
simulator = GBM_Simulation(s_0, iterations, num_paths, mu, sigma)
paths = simulator.monte_carlo()
mean_price = simulator.calculate_mean_price(paths)

# Analytical solution
pricer = GBM_Pricer(s_0, mu, sigma, t, W_t)
S_t = pricer.calculate_S_t()
print(f"Analytical solution for S(t) at t={t}: {S_t}")
# Out:
# The mean of the final stock prices from 100 simulated paths is: 1003.3261173738391
# S(t) = 448.1689070338065
# The mean of the final stock prices from 100 simulated paths is: 180.7364070722551
# Analytical solution for S(t) at t=10: 134.9858807576003
